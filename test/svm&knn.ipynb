# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %% [raw]
# ### dataset

# %%
iris = load_iris()

# %%
x = iris.data[:, :2]
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
x_min, x_max = x_train[:,0].min()-1, x_train[:,0].max()+1

# %%
y_min, y_max = x_train[:,1].min()-1, x_train[:,1].max()+1

# %%
xx, yy =np.meshgrid(np.linspace(x_min,x_max,300),np.linspace(y_min,y_max, 300))

# %%
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
Z= Z.reshape(xx.shape)

# %%
plt.contourf(xx,yy,Z, cmap=plt.cm.coolwarm ,alpha =0.8)
plt.scatter(x[:,0],x[:,1],c=y,cmap=plt.cm.coolwarm, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('SVM Decision Boundary')
plt.show()

# %%
y_pred= model.predict(x_test)

# %%
print("Iris Dataset Accuracy (Linear Kernel):", accuracy_score(y_test, y_pred))
# Out:
# Iris Dataset Accuracy (Linear Kernel): 0.9

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn = knn.predict(x_test)

# %%
print("Iris Dataset Accuracy (KNN, k=3):", accuracy_score(y_test, y_pred_knn))
# Out:
# Iris Dataset Accuracy (KNN, k=3): 0.8
